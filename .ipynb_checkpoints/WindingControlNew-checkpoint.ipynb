# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import glob
import os, os.path
import keras
import time
import scipy.misc
import scipy.ndimage

from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

from keras.utils import np_utils
from keras.optimizers import SGD
from keras.callbacks import CSVLogger
from keras import backend as K
from keras.initializers import RandomUniform, RandomNormal

from PIL import Image

from tqdm import tqdm

# %matplotlib inline

# %%
# resolution of images

x = 75
y = 100

# %%
#Loading training images
#Creates list of negative files

train_n_list = glob.glob('/fhgfs/groups/e5/lhcb/detector/scifi/windingcontrol/Images_sorted/NegTrain/*.bmp')
#Finds the number of negative files
train_n_len = len(train_n_list)
print("Size of negative Training Sample: {}".format(train_n_len))

#Same but for positive files
train_p_list = glob.glob('/fhgfs/groups/e5/lhcb/detector/scifi/windingcontrol/Images_sorted/PosTrain/*.bmp')
train_p_len = len(train_p_list)
print("Size of positive Training Sample: {}".format(train_p_len))

#Loading test images
#Creates list of negative files
test_n_list = glob.glob('/fhgfs/groups/e5/lhcb/detector/scifi/windingcontrol/Images_sorted/NegTest/*.bmp')

#Finds the number of negative files
test_n_len = len(test_n_list)
print("Size of negative Testing Sample: {}".format(test_n_len))


#Same but for positive files
test_p_list = glob.glob('/fhgfs/groups/e5/lhcb/detector/scifi/windingcontrol/Images_sorted/PosTest/*.bmp')
test_p_len = len(test_p_list)
print("Size of positive Testing Sample: {}".format(test_n_len))
# Out:
# Size of negative Training Sample: 5118
# Size of positive Training Sample: 5527
# Size of negative Testing Sample: 1000
# Size of positive Testing Sample: 1000

# %%
## Import and process image data

# Creates list of downward translated positive images 
X_train_posintd = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), # resize to wanted resolution
    (20,0) # tranlate downward 20px
    , output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
    for fname in tqdm(train_p_list)])

# Creates list of downward translated negative images 
X_train_negintd = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
    for fname in tqdm(train_n_list)])

# Creates list of upward translated positive images 
X_train_posintu = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)),# resize to wanted resolution
    (-20,0), # tranlate upward 20px
    output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
    for fname in tqdm(train_p_list)])

# Creates list of upward translated negative images
X_train_negintu = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (-20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
    for fname in tqdm(train_n_list)])

## List for images without translation
X_train_pos = np.array([scipy.misc.imresize(np.array(Image.open(fname)),(x,y)) for fname in tqdm(train_p_list)])

X_train_neg = np.array([scipy.misc.imresize(np.array(Image.open(fname)), (x,y)) for fname in tqdm(train_n_list)])
# Out:
# ...
# 100%|██████████| 5118/5118 [1:03:42<00:00,  1.06s/it]

# %%
# Same for test images

X_test_posintd = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
    for fname in tqdm(test_p_list)])

X_test_negintd = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
 for fname in tqdm(test_n_list)])

X_test_posintu = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (-20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
 for fname in tqdm(test_p_list)])

X_test_negintu = np.array([scipy.ndimage.interpolation.shift(
    scipy.misc.imresize(np.array(Image.open(fname)),(x,y)), (-20,0), output=None, order=1, mode='nearest', cval=0.0, prefilter=True) 
 for fname in tqdm(test_n_list)])



X_test_pos = np.array([scipy.misc.imresize(np.array(Image.open(fname)),(x,y)) for fname in tqdm(test_p_list)])

X_test_neg = np.array([scipy.misc.imresize(np.array(Image.open(fname)), (x,y)) for fname in tqdm(test_n_list)])
# Out:
# ...
# 100%|██████████| 1000/1000 [13:20<00:00,  1.92it/s]

# %%
X_train_posintd.shape
# Out:
# (5527, 75, 100)

# %%
#Formating the training data into numpy arrays
X_train = np.concatenate((X_train_posintd, X_train_posintu, X_train_pos, X_train_negintd, X_train_negintu, X_train_neg), axis=0)
#Merging both positive and negative results into one numpy array
X_test = np.concatenate((X_test_posintd, X_test_posintu, X_test_pos, X_test_negintd, X_test_negintu, X_test_neg), axis=0)


#Assigning classes to images (1 for negative, 0 for positive) and changing shape of numpy array
Y_train = np_utils.to_categorical(np.concatenate((np.zeros((3*train_n_len,1)), np.ones((3*train_p_len, 1))), axis=0), 2)
#Assigning classes to images (1 for negative, 0 for positive) and changing shape of numpy array
Y_test = np_utils.to_categorical(np.concatenate((np.zeros((3*test_n_len,1)), np.ones((3*test_p_len, 1))), axis=0), 2)


#Shuffling the order of the input - required to avoid batches selecting only positive/negative images
randomize = np.arange(len(X_train))
np.random.shuffle(randomize)
X_train = X_train[randomize]
Y_train = Y_train[randomize]

randomize = np.arange(len(X_test))
np.random.shuffle(randomize)
X_test = X_test[randomize]
Y_test = Y_test[randomize]

X_train = X_train.reshape(X_train.shape[0], x, y, 1)
X_test = X_test.reshape(X_test.shape[0], x, y, 1)

np.save(arr=X_train, file=open('../Data/X_train.npy', 'wb'))
np.save(arr=Y_train, file=open('../Data/Y_train.npy', 'wb'))
np.save(arr=X_test, file=open('../Data/X_test.npy', 'wb'))
np.save(arr=X_test, file=open('../Data/Y_test.npy', 'wb'))


#Shape check (NumberofImages, Height, Width, Depth)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (31935, 75, 100, 1)
# (31935, 2)
# (6000, 75, 100, 1)
# (6000, 2)

# %% [markdown]
# # Data need to be normalised
# * Mean and StdDev for each pixel over whole data set

# %%
means = np.mean(X_train, axis=0)
stds = np.std(X_train, axis=0)

# %%
print(means.shape)
print(stds.shape)
# Out:
# (75, 100, 1)
# (75, 100, 1)

# %%
X_train.shape
# Out:
# (31935, 75, 100, 1)

# %%
X_train_norm = np.array([(img-means)/stds for img in X_train])

# %%
X_train_norm.shape
# Out:
# (31935, 75, 100, 1)

# %%
X_test_norm = np.array([(img-means)/stds for img in X_test])

# %%
plt.imshow(np.squeeze(means), cmap='gray')
plt.savefig('../Data/Mean_img.png')

# %%
plt.imshow(np.squeeze(stds), cmap='gray')
plt.savefig('../Data/StdDev_img.png')

# %%
np.savetxt('../Data/Means.txt', np.transpose([means, stds]))

# %% [markdown]
# ## Test to normalise Data

# %%
X_New_Train = X_train[1205:1211]

# %%
X_New_Train.shape
# Out:
# (6, 75, 100, 1)

# %%
len(X_New_Train)
# Out:
# 6

# %%
num_img = len(X_New_Train)
n = int(np.ceil(np.sqrt(num_img)))

fig = plt.figure(figsize=(12,8))

for i,img in enumerate(X_New_Train):
    img_ = np.squeeze(img, axis=2)
    ax = fig.add_subplot(n,n,i+1)
    ax.imshow(img_, cmap='gray')

# %%
means = np.mean(X_New_Train, axis=0)
stds = np.std(X_New_Train, axis=0)

# %%
print(means.shape)
print(stds.shape)
# Out:
# (75, 100, 1)
# (75, 100, 1)

# %%
num_img = len(X_New_Train)
n = int(np.ceil(np.sqrt(num_img)))

fig = plt.figure(figsize=(12,8))

for i, (img, mean, std) in enumerate(zip(X_New_Train, means, stds)):
    img_new = (img-mean)/std
    img_ = np.squeeze(img_new, axis=2)
    ax = fig.add_subplot(n,n,i+1)
    ax.imshow(img_, cmap='gray')

# %% [markdown]
# # Let the training begin...

# %%
## Class to get loss and accuracy during training of NN

class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.accuracy = []
    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.accuracy.append(logs.get('acc'))

# %%
num_kernel = 9
kernel_size = 3
seed = 1234

input_shape= (x,y,1)

# %% [markdown]
# * initializer need to have mean = 0 and std 1/input_shape
# * for successive layers output shape of previous layer will declare this

# %%
model = Sequential()

# First Convolutional layer initialised with random input weights
model.add(Conv2D(8, (13,13), kernel_initializer=RandomNormal(mean=0, stddev=1/(x*y), seed=seed), input_shape=input_shape, activation='selu'))
model.add(MaxPooling2D(pool_size=(2,2)))

print(model.layers[1].output_shape)
mult_shape1 = model.layers[1].output_shape[1]*model.layers[1].output_shape[2]*model.layers[1].output_shape[3]
print(mult_shape1)

# Second Convolutional layer
model.add(Conv2D(8, (11,11), kernel_initializer=RandomNormal(mean=0, stddev=1/mult_shape1, seed=seed), activation='selu'))
model.add(MaxPooling2D(pool_size=(2,2)))

print(model.layers[3].output_shape)
mult_shape2 = model.layers[3].output_shape[1]*model.layers[3].output_shape[2]*model.layers[3].output_shape[3]
print(mult_shape2)

# Third Convolutional layer
model.add(Conv2D(16, (9,9), kernel_initializer=RandomNormal(mean=0, stddev=1/mult_shape2, seed=seed), activation='selu'))
model.add(MaxPooling2D(pool_size=(2,2)))

print(model.layers[5].output_shape)
mult_shape3 = model.layers[5].output_shape[1]*model.layers[5].output_shape[2]*model.layers[5].output_shape[3]
print(mult_shape3)

# Fourth Convolutional layer
model.add(Conv2D(16, (7,7), kernel_initializer=RandomNormal(mean=0, stddev=1/mult_shape3, seed=seed), activation='selu'))
model.add(MaxPooling2D(pool_size=(2,2)))

print(model.layers[7].output_shape)

#Converting the 2D images to 1D vectors
model.add(Flatten())  

#Fully connected layer
model.add(Dense(32, activation='selu'))

#Fully connected layer
model.add(Dense(32, activation='selu'))
model.add(Dropout(0.5))

#Output layer
model.add(Dense(2, activation='softmax'))
# Out:
# (None, 31, 44, 8)
# 10912
# (None, 10, 17, 8)
# 1360
# (None, 1, 4, 16)
# 64
# (None, -3, -1, 16)
# INFO (theano.gof.compilelock): Refreshing lock /home/jmueller/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.9-Carbon-x86_64-3.6.1-64/lock_dir/lock
# INFO:theano.gof.compilelock:Refreshing lock /home/jmueller/.theano/compiledir_Linux-2.6-el6.x86_64-x86_64-with-redhat-6.9-Carbon-x86_64-3.6.1-64/lock_dir/lock

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_60 (Conv2D)           (None, 63, 88, 8)         1360
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 31, 44, 8)         0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 19, 32, 16)        21648
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 9, 16, 16)         0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, -1, 6, 16)         30992
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, -1, 3, 16)         0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, -9, -5, 16)        20752
# ...

# %%
#Defining optimiser and compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
        
history = LossHistory()
model.fit(X_train_norm, Y_train,  batch_size=32, epochs=12, verbose=1, validation_split = 0.1, callbacks=[history])

#Evaluating trained model on test images
score = model.evaluate(X_test_norm, Y_test, verbose=0)
print('Model has accuracy:', score[1]*100,'%')
# Out:
# ERROR (theano.gof.opt): SeqOptimizer apply <theano.tensor.opt.ShapeOptimizer object at 0x7f743692ee48>
# ERROR (theano.gof.opt): Traceback:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/opt/rh/miniconda/envs/ml_theano_keras/lib/python3.6/site-packages/theano/gof/opt.py", line 235, in apply
#     sub_prof = optimizer.optimize(fgraph)
#   File "/opt/rh/miniconda/envs/ml_theano_keras/lib/python3.6/site-packages/theano/gof/opt.py", line 83, in optimize
#     self.add_requirements(fgraph)
#   File "/opt/rh/miniconda/envs/ml_theano_keras/lib/python3.6/site-packages/theano/tensor/opt.py", line 1482, in add_requirements
#     fgraph.attach_feature(ShapeFeature())
#   File "/opt/rh/miniconda/envs/ml_theano_keras/lib/python3.6/site-packages/theano/gof/fg.py", line 541, in attach_feature
#     attach(self)
#   File "/opt/rh/miniconda/envs/ml_theano_keras/lib/python3.6/site-packages/theano/tensor/opt.py", line 1299, in on_attach
# ...

# %%
score
# Out:
# [0.089304745743672059, 0.96816666666666662]

# %%
#To save trained NN - USE DIFFERENT NAME FOR NEW NETWORK
model.save('../TrainedModels/93_93_93_32_32.h5')

# %%
np.savetxt('../Data/93_93_93_32_32_TrainingData.txt', np.transpose([history.accuracy, history.losses]))

# %%
ACC = np.array(history.accuracy)
LOSS = np.array(history.losses)
#print(np.array(history.losses).shape)

plt.figure(figsize=(15,10))
plt.plot(ACC)
plt.ylabel('accuracy')
plt.xlabel('batch number')
plt.show()
#plt.savefig('11conv_accuracy.png')

plt.figure(figsize=(15,10))
plt.plot(LOSS)
plt.ylabel('loss')
plt.xlabel('batch number')
plt.show()
#plt.savefig('11conv_loss.png')

# %% [markdown]
# # Look at saved models

# %%
test_model = load_model('../TrainedModels/93_93_93_32_32.h5')

# %%
#Evaluating trained model on test images
score = test_model.evaluate(X_test_norm, Y_test, verbose=0)
print('Model has accuracy:', score[1]*100,'%')
# Out:
# Model has accuracy: 52.2166666667 %

# %%
accuracy, losses = np.genfromtxt('../Data/93_93_93_32_32_TrainingData.txt', unpack=True)

# %%
fig, ax = plt.subplots(2, sharex=True)

ax[0].plot(accuracy, color = 'b', marker='', ls='-')
ax[1].plot(losses, color = 'm', marker='', ls='-')

ax[1].set_xlabel('batch number')
ax[0].set_ylabel('accuracy')
ax[1].set_ylabel('loss')
